# %%
import json
stub = 'http://dx.doi.org/'
dois=[]
with open('out.json') as f:
    j = json.load(f)
    print(len(j))
    j.remove({})
    print(len(j))
    for rec in j:
        print(rec)
        doi = stub+rec['doi'] 
        dois.append(doi)
dois
# Out:
# 66
# 65
# {u'doi': u'10.1002/cmdc.201500424', u'cross_ref_doi': True, u'title': u'How Consistent are Publicly Reported Cytotoxicity Data? Large-Scale Statistical Analysis of the Concordance of Public Independent Cytotoxicity Measurements'}
# {u'doi': u'10.1002/anie.201508912', u'cross_ref_doi': True, u'title': u'Ligand-Enabled Catalytic C\uf8ffH Arylation of Aliphatic Amines by a Four-Membered-Ring Cyclopalladation Pathway'}
# {u'doi': u'10.1016/j.bbrc.2015.11.018', u'cross_ref_doi': True, u'title': u'Solvent exposure of Tyr10 as a probe of structural differences between monomeric and aggregated forms of the amyloid-\u03b2 peptide'}
# {u'doi': u'10.1021/jacs.5b07849', u'cross_ref_doi': True, u'title': u'N-Terminal Extensions Retard A\u03b242 Fibril Formation but Allow Cross-Seeding and Coaggregation with A\u03b242'}
# {u'doi': u'10.1016/j.bpj.2015.09.004', u'cross_ref_doi': True, u'title': u'Referenced Single-Molecule Measurements Differentiate between GPCR Oligomerization States'}
# ...
